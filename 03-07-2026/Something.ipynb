# %% [markdown]
# Topic:
# 1. Handle categorical variables
# 2. Perform categorical analysis
# 3. Compare and order categories
# 4. Rename categories

# %%
import pandas as pd

data = pd.DataFrame({
  "ID":[101 , 102 , 103 , 104 , 105 , 106 , 107 , 108],
  "Name":["Amit" , "Pooja" , "Arti" , "Priya" , "Neha" , "Rohan",  "Rahul" , "Sneha"],
  "Gender":["Male" , "Female" , "Female" , "Female" , "Female" , "Male" , "Male" , "Female"],
  "Department":["IT" , "HR" , "Finance" , "IT" , "HR" , "Finance" , "HR" , "IT"],
  "Performance":["Good" , "Excellent" , "Average" ,  "Good" , "Average",  "Average",  "Excellent" , "Excellent"]
})

print(data)
# Out:
#     ID   Name  Gender Department Performance
# 0  101   Amit    Male         IT        Good
# 1  102  Pooja  Female         HR   Excellent
# 2  103   Arti  Female    Finance     Average
# 3  104  Priya  Female         IT        Good
# 4  105   Neha  Female         HR     Average
# 5  106  Rohan    Male    Finance     Average
# 6  107  Rahul    Male         HR   Excellent
# 7  108  Sneha  Female         IT   Excellent

# %%
data["Gender"] = data["Gender"].astype("category")
data["Department"] = data["Department"].astype("category")
data["Performance"] = data["Performance"].astype("category")

print(data.dtypes)

print(data["Gender"].cat.categories)

print(data["Department"].cat.categories)

print(data["Performance"].cat.categories)

print(data["Gender"].cat.codes)

print(data["Department"].cat.codes)
# Out:
# ID                int64
# Name                str
# Gender         category
# Department     category
# Performance    category
# dtype: object
# Index(['Female', 'Male'], dtype='str')
# Index(['Finance', 'HR', 'IT'], dtype='str')
# Index(['Average', 'Excellent', 'Good'], dtype='str')
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# 5    1
# 6    1
# 7    0
# dtype: int8
# 0    2
# 1    1
# 2    0
# 3    2
# 4    1
# 5    0
# 6    1
# 7    2
# dtype: int8

# %% [markdown]
# #### Categorial Analysis

# %%
print(data["Department"].value_counts())
print(data["Gender"].value_counts())
print(data["Performance"].value_counts())
print(data["Department"].value_counts(normalize = True) * 100)
print(data["Gender"].value_counts(normalize = True) * 100)
print(data["Performance"].value_counts(normalize = True) * 100)
print(data["Department"].unique())
print(data["Department"].nunique())
print(data.nunique())
# Out:
# Department
# HR         3
# IT         3
# Finance    2
# Name: count, dtype: int64
# Gender
# Female    5
# Male      3
# Name: count, dtype: int64
# Performance
# Average      3
# Excellent    3
# Good         2
# Name: count, dtype: int64
# Department
# HR         37.5
# IT         37.5
# Finance    25.0
# Name: proportion, dtype: float64
# Gender
# Female    62.5
# Male      37.5
# Name: proportion, dtype: float64
# Performance
# Average      37.5
# Excellent    37.5
# Good         25.0
# Name: proportion, dtype: float64
# ['IT', 'HR', 'Finance']
# Categories (3, str): ['Finance', 'HR', 'IT']
# 3
# ID             8
# Name           8
# Gender         2
# Department     3
# Performance    3
# dtype: int64

# %% [markdown]
# #### Compare and order categories

# %%
data["Performance"] = data["Performance"].cat.reorder_categories(['Good' , 'Average' , 'Excellent'] , ordered=True)

print(data["Performance"].cat.categories)

print(data.sort_values("Performance"))

print(data[data["Performance"] == "Good"])
# Out:
# Index(['Good', 'Average', 'Excellent'], dtype='str')
#     ID   Name  Gender Department Performance
# 0  101   Amit    Male         IT        Good
# 3  104  Priya  Female         IT        Good
# 2  103   Arti  Female    Finance     Average
# 4  105   Neha  Female         HR     Average
# 5  106  Rohan    Male    Finance     Average
# 1  102  Pooja  Female         HR   Excellent
# 6  107  Rahul    Male         HR   Excellent
# 7  108  Sneha  Female         IT   Excellent
#     ID   Name  Gender Department Performance
# 0  101   Amit    Male         IT        Good
# 3  104  Priya  Female         IT        Good

# %% [markdown]
# #### Rename Categories

# %%
data["Department"] = data["Department"].cat.rename_categories({
"Information Technologys" : "IT",
"Human Resources" : "HR",
"Account" : "Finance"
})

print(data["Department"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data["Department"] = data["Department"].cat.rename_categories({
#       2 "Information Technologys" : "IT",
#       3 "Human Resources" : "HR",
#       4 "Account" : "Finance"
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2978, in CategoricalAccessor.__init__(self, data)
#    2977 def __init__(self, data) -> None:
# -> 2978     self._validate(data)
#    2979     self._parent = data.values
#    2980     self._index = data.index
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2987, in CategoricalAccessor._validate(data)
#    2984 @staticmethod
#    2985 def _validate(data) -> None:
#    2986     if not isinstance(data.dtype, CategoricalDtype):
# -> 2987         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
print(data)
# Out:
#     ID   Name  Gender Department Performance
# 0  101   Amit    Male         IT        Good
# 1  102  Pooja  Female         HR   Excellent
# 2  103   Arti  Female    Finance     Average
# 3  104  Priya  Female         IT        Good
# 4  105   Neha  Female         HR     Average
# 5  106  Rohan    Male    Finance     Average
# 6  107  Rahul    Male         HR   Excellent
# 7  108  Sneha  Female         IT   Excellent

# %%
data["Department"] = data["Department"].cat.add_categories(["Developmentsss"])

print(data["Department"].cat.categories)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data["Department"] = data["Department"].cat.add_categories(["Developmentsss"])
#       2
#       3 print(data["Department"].cat.categories)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2978, in CategoricalAccessor.__init__(self, data)
#    2977 def __init__(self, data) -> None:
# -> 2978     self._validate(data)
#    2979     self._parent = data.values
#    2980     self._index = data.index
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2987, in CategoricalAccessor._validate(data)
#    2984 @staticmethod
#    2985 def _validate(data) -> None:
#    2986     if not isinstance(data.dtype, CategoricalDtype):
# -> 2987         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
data["Department"] = data["Department"].cat.unused_categories()

print(data["Department"].cat.categories)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data["Department"] = data["Department"].cat.unused_categories()
#       2
#       3 print(data["Department"].cat.categories)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2978, in CategoricalAccessor.__init__(self, data)
#    2977 def __init__(self, data) -> None:
# -> 2978     self._validate(data)
#    2979     self._parent = data.values
#    2980     self._index = data.index
#
# File d:\AMAZON\ALL IN 1 BACK\Python Source\Lib\site-packages\pandas\core\arrays\categorical.py:2987, in CategoricalAccessor._validate(data)
#    2984 @staticmethod
#    2985 def _validate(data) -> None:
#    2986     if not isinstance(data.dtype, CategoricalDtype):
# -> 2987         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
print(data)
# Out:
#     ID   Name  Gender Department Performance
# 0  101   Amit    Male         IT        Good
# 1  102  Pooja  Female         HR   Excellent
# 2  103   Arti  Female    Finance     Average
# 3  104  Priya  Female         IT        Good
# 4  105   Neha  Female         HR     Average
# 5  106  Rohan    Male    Finance     Average
# 6  107  Rahul    Male         HR   Excellent
# 7  108  Sneha  Female         IT   Excellent
